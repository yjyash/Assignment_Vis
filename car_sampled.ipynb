# %%
import pandas as pd
import seaborn as sns

# %%
da=pd.read_csv('//content//cars_sampled.csv')

da
# Out:
#             dateCrawled                                               name  \
# 0      30/03/2016 13:51                                       Zu_verkaufen
# 1         7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 2         1/4/2016 0:57                                  Volkswagen_Touran
# 3      19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4      16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
# ...                 ...                                                ...
# 49996    3/4/2016 15:48                               Suche_VW_T5_Multivan
# 49997  27/03/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 49998  14/03/2016 18:51  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# 49999  15/03/2016 18:06        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 50000   22/03/2016 9:54                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType  price   abtest    vehicleType  \
# ...

# %%
da.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'postalCode', 'lastSeen'],
#       dtype='object')

# %%
da.head()
# Out:
#         dateCrawled                                               name  \
# 0  30/03/2016 13:51                                       Zu_verkaufen
# 1     7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 2     1/4/2016 0:57                                  Volkswagen_Touran
# 3  19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4  16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
#
#     seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0  private     offer   4450     test   limousine                2003
# 1  private     offer  13299  control         suv                2005
# 2  private     offer   3200     test         bus                2003
# 3  private     offer   4500  control   small car                2006
# 4  private     offer  18750     test         suv                2008
#
#      gearbox  powerPS     model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
da.tail()
# Out:
#             dateCrawled                                               name  \
# 49996    3/4/2016 15:48                               Suche_VW_T5_Multivan
# 49997  27/03/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 49998  14/03/2016 18:51  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# 49999  15/03/2016 18:06        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 50000   22/03/2016 9:54                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType  price   abtest    vehicleType  \
# 49996     private   request      0     test            bus
# 49997     private   request  19999  control            NaN
# 49998     private   request      0     test          coupe
# 49999  commercial     offer    100  control  station wagon
# 50000  commercial     offer   1100     test      small car
#
#        yearOfRegistration gearbox  powerPS        model  kilometer  \
# 49996                2005     NaN        0  transporter     150000
# ...

# %%
da.isna().sum()
# Out:
# dateCrawled               0
# name                      0
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            5188
# yearOfRegistration        0
# gearbox                2824
# powerPS                   0
# model                  2758
# kilometer                 0
# monthOfRegistration       0
# fuelType               4503
# brand                     0
# notRepairedDamage      9716
# dateCreated               0
# postalCode                0
# lastSeen                  0
# dtype: int64

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50001 entries, 0 to 50000
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50001 non-null  object
#  1   name                 50001 non-null  object
#  2   seller               50001 non-null  object
#  3   offerType            50001 non-null  object
#  4   price                50001 non-null  int64
#  5   abtest               50001 non-null  object
#  6   vehicleType          44813 non-null  object
#  7   yearOfRegistration   50001 non-null  int64
#  8   gearbox              47177 non-null  object
#  9   powerPS              50001 non-null  int64
#  10  model                47243 non-null  object
#  11  kilometer            50001 non-null  int64
#  12  monthOfRegistration  50001 non-null  int64
#  13  fuelType             45498 non-null  object
#  14  brand                50001 non-null  object
# ...

# %%
da.describe()
# Out:
#               price  yearOfRegistration       powerPS      kilometer  \
# count  5.000100e+04        50001.000000  50001.000000   50001.000000
# mean   6.559865e+03         2005.544229    116.496130  125613.687726
# std    8.581847e+04          122.991832    230.567709   40205.234483
# min    0.000000e+00         1000.000000      0.000000    5000.000000
# 25%    1.150000e+03         1999.000000     69.000000  125000.000000
# 50%    2.950000e+03         2003.000000    105.000000  150000.000000
# 75%    7.190000e+03         2008.000000    150.000000  150000.000000
# max    1.234568e+07         9999.000000  19312.000000  150000.000000
#
#        monthOfRegistration    postalCode
# count         50001.000000  50001.000000
# mean              5.743725  50775.216696
# std               3.711345  25743.701933
# min               0.000000   1067.000000
# 25%               3.000000  30559.000000
# 50%               6.000000  49504.000000
# 75%               9.000000  71404.000000
# ...

# %%
da.corr()
# Out:
# <ipython-input-16-c07a06891de5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   da.corr()
#                         price  yearOfRegistration   powerPS  kilometer  \
# price                1.000000            0.017604  0.020429  -0.045458
# yearOfRegistration   0.017604            1.000000 -0.004394  -0.064188
# powerPS              0.020429           -0.004394  1.000000  -0.016447
# kilometer           -0.045458           -0.064188 -0.016447   1.000000
# monthOfRegistration  0.000582           -0.023152  0.034345   0.001985
# postalCode           0.005916           -0.001615  0.017415  -0.024076
#
#                      monthOfRegistration  postalCode
# price                           0.000582    0.005916
# yearOfRegistration             -0.023152   -0.001615
# ...

# %%
sns.heatmap(da.corr(),annot=True)
# Out:
# <ipython-input-18-4df85168c021>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(da.corr(),annot=True)
# <Axes: >
