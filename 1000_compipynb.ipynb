# %%
import pandas as pd

da=pd.read_csv('//content//1000_Companies.csv')
print(da)
#da['State'].unique()
da.groupby(['State'])['Profit','Marketing Spend','Administration','R&D Spend'].sum()
# Out:
#      R&D Spend  Administration  Marketing Spend       State        Profit
# 0    165349.20      136897.800      471784.1000    New York  192261.83000
# 1    162597.70      151377.590      443898.5300  California  191792.06000
# 2    153441.51      101145.550      407934.5400     Florida  191050.39000
# 3    144372.41      118671.850      383199.6200    New York  182901.99000
# 4    142107.34       91391.770      366168.4200     Florida  166187.94000
# ..         ...             ...              ...         ...           ...
# 995   54135.00      118451.999      173232.6695  California   95279.96251
# 996  134970.00      130390.080      329204.0228  California  164336.60550
# 997  100275.47      241926.310      227142.8200  California  413956.48000
# 998  128456.23      321652.140      281692.3200  California  333962.19000
# 999  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [1000 rows x 5 columns]
# ...

# %%
#EDA: Explore data analysis:
#1.Which are the columns or column information
#2.Top rows
#3.Bottom Rows
#4.technical summary:: datatypes of all the columns and check is their
#5.any null present
#6.statistical summary: mean,min,max,avg,count
#7.correlation between numerical parameters
#8.experiment how each input affect for predicting the profit
#9.if data distribution is not normalize apply appropriate method to analyse data
#10.if any catagorical data is present lets convert it into numeric

# %%
da.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
#da.head(5)
da.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#da.tail(10)
da.tail()
# Out:
#      R&D Spend  Administration  Marketing Spend       State        Profit
# 990  136133.00     130561.8371      331448.0344  California  165330.14630
# 991  131106.00     129819.4269      321748.4242    New York  161035.62360
# 992  105127.00     125982.7298      271621.8728     Florida  138841.98810
# 993   46798.00     117368.4374      159075.9080  California   89012.02672
# 994   97209.00     124813.3635      256344.0701    New York  132077.70900
# 995   54135.00     118451.9990      173232.6695  California   95279.96251
# 996  134970.00     130390.0800      329204.0228  California  164336.60550
# 997  100275.47     241926.3100      227142.8200  California  413956.48000
# 998  128456.23     321652.1400      281692.3200  California  333962.19000
# 999  161181.72     270939.8600      295442.1700    New York  476485.43000

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        1000 non-null   float64
#  1   Administration   1000 non-null   float64
#  2   Marketing Spend  1000 non-null   float64
#  3   State            1000 non-null   object
#  4   Profit           1000 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB

# %%
da.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count    1000.000000     1000.000000      1000.000000    1000.000000
# mean    81668.927200   122963.897612    226205.058419  119546.164656
# std     46537.567891    12613.927535     91578.393542   42888.633848
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     43084.500000   116640.684850    150969.584600   85943.198543
# 50%     79936.000000   122421.612150    224517.887350  117641.466300
# 75%    124565.500000   129139.118000    308189.808525  155577.107425
# max    165349.200000   321652.140000    471784.100000  476485.430000

# %%
da['Administration'].describe()
# Out:
# count      1000.000000
# mean     122963.897612
# std       12613.927535
# min       51283.140000
# 25%      116640.684850
# 50%      122421.612150
# 75%      129139.118000
# max      321652.140000
# Name: Administration, dtype: float64

# %%
da['State'].values_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-31ecbdd27f1c> in <cell line: 1>()
# ----> 1 da['State'].values_count()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'values_count'

# %%
da.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
da.corr()
# Out:
# <ipython-input-48-c07a06891de5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   da.corr()
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.582434         0.978407  0.945245
# Administration    0.582434        1.000000         0.520465  0.741560
# Marketing Spend   0.978407        0.520465         1.000000  0.917270
# Profit            0.945245        0.741560         0.917270  1.000000

# %%
import seaborn as sns
sns.heatmap(da.corr(),annot=True)
# Out:
# <ipython-input-51-c180d4c7b715>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(da.corr(),annot=True)
# <Axes: >
